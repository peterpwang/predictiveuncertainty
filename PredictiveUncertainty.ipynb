# %% [markdown]
# Include all related libraries.

# %%
import tensorflow as tf                                                                         
from tensorflow import keras                                                                    
from tensorflow.keras import datasets, layers, models                                           
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD
from classes import abstractmodel, cifar10model

# %%
#z-score
#mean = np.mean(train_images,axis=(0,1,2,3))
#std = np.std(train_images,axis=(0,1,2,3))
#train_images = (train_images-mean)/(std+1e-7)
#test_images = (test_images-mean)/(std+1e-7)

# %%
vgg3ddamodel = cifar10model.VGG3DropoutDataAugumentationCIFAR10Model(10, 10, 64)
vgg3ddamodel.run()
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-ababfca1c5ff> in <module>
#       1 vgg3ddamodel = cifar10model.VGG3DropoutDataAugumentationCIFAR10Model(10, 10, 64)
# ----> 2 vgg3ddamodel.run()
#
# ~/code/predictiveuncertainty/classes/cifar10model.py in run(self)
#     136
#     137         acc = model.evaluate(test_images, test_labels, verbose=0)
# --> 138         print('> %.3f' % (acc * 100.0))
#     139
#     140         self.display_results(history)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
class VGG3DropoutCIFAR10Model(cifar10model.AbstractCIFAR10ImageClassificationModel):
    
    # Set model
    def define_model(self):
        model = Sequential()
        model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
        model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(MaxPooling2D((2, 2)))
        model.add(Dropout(0.2))
        model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(MaxPooling2D((2, 2)))
        model.add(Dropout(0.2))
        model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(MaxPooling2D((2, 2)))
        model.add(Dropout(0.2))
        model.add(Flatten())
        model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
        model.add(Dropout(0.2))
        model.add(Dense(10, activation='softmax'))
        
        # compile model
        opt = SGD(lr=0.001, momentum=0.9)
        model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
        return model
    
vgg3dropoutmodel = VGG3DropoutCIFAR10Model(10, 10, 64)
vgg3dropoutmodel.run()
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 343s 7ms/sample - loss: 1.9947 - accuracy: 0.2604 - val_loss: 1.7016 - val_accuracy: 0.3894
# Epoch 2/10
# 50000/50000 [==============================] - 311s 6ms/sample - loss: 1.6382 - accuracy: 0.3991 - val_loss: 1.4731 - val_accuracy: 0.4643
# Epoch 3/10
# 50000/50000 [==============================] - 299s 6ms/sample - loss: 1.4884 - accuracy: 0.4572 - val_loss: 1.3539 - val_accuracy: 0.5141
# Epoch 4/10
# 50000/50000 [==============================] - 292s 6ms/sample - loss: 1.3894 - accuracy: 0.4979 - val_loss: 1.2967 - val_accuracy: 0.5356
# Epoch 5/10
# 50000/50000 [==============================] - 20826s 417ms/sample - loss: 1.3072 - accuracy: 0.5288 - val_loss: 1.1772 - val_accuracy: 0.5806
# Epoch 6/10
# 50000/50000 [==============================] - 38855s 777ms/sample - loss: 1.2444 - accuracy: 0.5518 - val_loss: 1.1114 - val_accuracy: 0.6097
# Epoch 7/10
# 50000/50000 [==============================] - 17265s 345ms/sample - loss: 1.1809 - accuracy: 0.5773 - val_loss: 1.0607 - val_accuracy: 0.6217
# Epoch 8/10
# 50000/50000 [==============================] - 318s 6ms/sample - loss: 1.1265 - accuracy: 0.5967 - val_loss: 1.0252 - val_accuracy: 0.6335
# Epoch 9/10
# 50000/50000 [==============================] - 295s 6ms/sample - loss: 1.0732 - accuracy: 0.6148 - val_loss: 0.9696 - val_accuracy: 0.6569
# Epoch 10/10
# 50000/50000 [==============================] - 321s 6ms/sample - loss: 1.0272 - accuracy: 0.6331 - val_loss: 0.9380 - val_accuracy: 0.6672
# > 66.720

# %%
class VGG3CIFAR10Model(cifar10model.AbstractCIFAR10ImageClassificationModel):
    
    # Set model
    def define_model(self):
        model = Sequential()
        model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
        model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(MaxPooling2D((2, 2)))
        model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(MaxPooling2D((2, 2)))
        model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(MaxPooling2D((2, 2)))
        model.add(Flatten())
        model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
        model.add(Dense(10, activation='softmax'))
        
        # compile model
        opt = SGD(lr=0.001, momentum=0.9)
        model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
        return model
    
vgg3model = VGG3CIFAR10Model(10, 10, 64)
vgg3model.run()
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 305s 6ms/sample - loss: 1.7424 - accuracy: 0.3677 - val_loss: 1.5341 - val_accuracy: 0.4407
# Epoch 2/10
# 50000/50000 [==============================] - 272s 5ms/sample - loss: 1.3961 - accuracy: 0.4985 - val_loss: 1.3596 - val_accuracy: 0.5087
# Epoch 3/10
# 50000/50000 [==============================] - 277s 6ms/sample - loss: 1.2217 - accuracy: 0.5632 - val_loss: 1.2782 - val_accuracy: 0.5451
# Epoch 4/10
# 50000/50000 [==============================] - 284s 6ms/sample - loss: 1.0985 - accuracy: 0.6121 - val_loss: 1.1107 - val_accuracy: 0.6119
# Epoch 5/10
# 50000/50000 [==============================] - 280s 6ms/sample - loss: 0.9979 - accuracy: 0.6503 - val_loss: 1.0768 - val_accuracy: 0.6210
# Epoch 6/10
# 50000/50000 [==============================] - 2994s 60ms/sample - loss: 0.9100 - accuracy: 0.6816 - val_loss: 0.9742 - val_accuracy: 0.6598
# Epoch 7/10
# 50000/50000 [==============================] - 268s 5ms/sample - loss: 0.8408 - accuracy: 0.7075 - val_loss: 0.9813 - val_accuracy: 0.6578
# Epoch 8/10
# 50000/50000 [==============================] - 280s 6ms/sample - loss: 0.7772 - accuracy: 0.7300 - val_loss: 0.9224 - val_accuracy: 0.6755
# Epoch 9/10
# 50000/50000 [==============================] - 268s 5ms/sample - loss: 0.7181 - accuracy: 0.7508 - val_loss: 0.9365 - val_accuracy: 0.6765
# Epoch 10/10
# 50000/50000 [==============================] - 269s 5ms/sample - loss: 0.6655 - accuracy: 0.7689 - val_loss: 0.8803 - val_accuracy: 0.7004
# > 70.040
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f35ddaf79ac7> in <module>
#      23
#      24 vgg3model = VGG3CIFAR10Model(10, 10, 64)
# ---> 25 vgg3model.run()
#
# ~/code/predictiveuncertainty/classes/abstractmodel.py in run(self)
#      80         print('> %.3f' % (acc * 100.0))
#      81
# ---> 82         self.display_results(history)
#      83
#      84
#
# NameError: name 'display_results' is not defined

# %%
class VGG2CIFAR10Model(cifar10model.AbstractCIFAR10ImageClassificationModel):
    
    # Set model
    def define_model(self):
        model = Sequential()
        model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
        model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(MaxPooling2D((2, 2)))
        model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(MaxPooling2D((2, 2)))
        model.add(Flatten())
        model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
        model.add(Dense(10, activation='softmax'))
        
        # compile model
        opt = SGD(lr=0.001, momentum=0.9)
        model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
        return model
    
vgg2model = VGG2CIFAR10Model(10, 10, 64)
vgg2model.run()
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 211s 4ms/sample - loss: 1.8013 - accuracy: 0.3524 - val_loss: 1.4696 - val_accuracy: 0.4713
# Epoch 2/10
# 50000/50000 [==============================] - 204s 4ms/sample - loss: 1.4135 - accuracy: 0.4954 - val_loss: 1.3418 - val_accuracy: 0.5123
# Epoch 3/10
# 50000/50000 [==============================] - 212s 4ms/sample - loss: 1.2604 - accuracy: 0.5532 - val_loss: 1.1928 - val_accuracy: 0.5821
# Epoch 4/10
# 50000/50000 [==============================] - 1733s 35ms/sample - loss: 1.1440 - accuracy: 0.5992 - val_loss: 1.1412 - val_accuracy: 0.5982
# Epoch 5/10
# 50000/50000 [==============================] - 193s 4ms/sample - loss: 1.0513 - accuracy: 0.6334 - val_loss: 1.0914 - val_accuracy: 0.6186
# Epoch 6/10
# 50000/50000 [==============================] - 195s 4ms/sample - loss: 0.9756 - accuracy: 0.6603 - val_loss: 1.0238 - val_accuracy: 0.6433
# Epoch 7/10
# 50000/50000 [==============================] - 1674s 33ms/sample - loss: 0.9140 - accuracy: 0.6823 - val_loss: 1.0111 - val_accuracy: 0.6489
# Epoch 8/10
# 50000/50000 [==============================] - 194s 4ms/sample - loss: 0.8534 - accuracy: 0.7060 - val_loss: 0.9581 - val_accuracy: 0.6768
# Epoch 9/10
# 50000/50000 [==============================] - 197s 4ms/sample - loss: 0.7955 - accuracy: 0.7246 - val_loss: 0.9550 - val_accuracy: 0.6699
# Epoch 10/10
# 50000/50000 [==============================] - 191s 4ms/sample - loss: 0.7453 - accuracy: 0.7414 - val_loss: 0.9406 - val_accuracy: 0.6796
# > 67.960
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a8a69464e700> in <module>
#      20
#      21 vgg2model = VGG2CIFAR10Model(10, 10, 64)
# ---> 22 vgg2model.run()
#
# ~/code/predictiveuncertainty/classes/abstractmodel.py in run(self)
#      80         print('> %.3f' % (acc * 100.0))
#      81
# ---> 82         self.display_results(history)
#      83
#      84
#
# NameError: name 'display_results' is not defined

# %%
class VGG1CIFAR10Model(cifar10model.AbstractCIFAR10ImageClassificationModel):
    
    # Set model
    def define_model(self):
        model = Sequential()
        model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
        model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(MaxPooling2D((2, 2)))
        model.add(Flatten())
        model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
        model.add(Dense(10, activation='softmax'))
        
        # compile model
        opt = SGD(lr=0.001, momentum=0.9)
        model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
        return model
    
vgg1model = VGG1CIFAR10Model(10, 10, 64)
vgg1model.run()
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 130s 3ms/sample - loss: 1.7780 - accuracy: 0.3648 - val_loss: 1.5435 - val_accuracy: 0.4421
# Epoch 2/10
# 50000/50000 [==============================] - 121s 2ms/sample - loss: 1.4202 - accuracy: 0.4909 - val_loss: 1.3497 - val_accuracy: 0.5218
# Epoch 3/10
# 50000/50000 [==============================] - 117s 2ms/sample - loss: 1.2688 - accuracy: 0.5497 - val_loss: 1.2607 - val_accuracy: 0.5485
# Epoch 4/10
# 50000/50000 [==============================] - 118s 2ms/sample - loss: 1.1594 - accuracy: 0.5922 - val_loss: 1.1706 - val_accuracy: 0.5883
# Epoch 5/10
# 50000/50000 [==============================] - 134s 3ms/sample - loss: 1.0774 - accuracy: 0.6209 - val_loss: 1.0994 - val_accuracy: 0.6108
# Epoch 6/10
# 50000/50000 [==============================] - 121s 2ms/sample - loss: 1.0122 - accuracy: 0.6459 - val_loss: 1.0733 - val_accuracy: 0.6278
# Epoch 7/10
# 50000/50000 [==============================] - 116s 2ms/sample - loss: 0.9550 - accuracy: 0.6668 - val_loss: 1.0492 - val_accuracy: 0.6287
# Epoch 8/10
# 50000/50000 [==============================] - 123s 2ms/sample - loss: 0.9011 - accuracy: 0.6846 - val_loss: 1.0153 - val_accuracy: 0.6437
# Epoch 9/10
# 50000/50000 [==============================] - 137s 3ms/sample - loss: 0.8579 - accuracy: 0.7009 - val_loss: 0.9945 - val_accuracy: 0.6548
# Epoch 10/10
# 50000/50000 [==============================] - 126s 3ms/sample - loss: 0.8104 - accuracy: 0.7190 - val_loss: 0.9940 - val_accuracy: 0.6532
# > 65.320
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7fe6a4f920c2> in <module>
#      17
#      18 vgg1model = VGG1CIFAR10Model(10, 10, 64)
# ---> 19 vgg1model.run()
#
# ~/code/predictiveuncertainty/classes/abstractmodel.py in run(self)
#      80         print('> %.3f' % (acc * 100.0))
#      81
# ---> 82         self.display_results(history)
#      83
#      84
#
# NameError: name 'display_results' is not defined

# %%
def define_model():
    #weight_decay = 1e-4

    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), 
                        padding="same", 
                        activation='relu',
                        kernel_initializer='he_uniform',
                        #kernel_regularizer=keras.regularizers.l2(weight_decay), 
                        input_shape=(32,32,3)))
#model.add(layers.Activation('elu')) 
#model.add(layers.BatchNormalization())
#model.add(layers.Conv2D(32, (3, 3), 
#                        padding="same", 
#                        activation='relu',
#                        #kernel_regularizer=keras.regularizers.l2(weight_decay), 
#                        input_shape=train_images.shape[1:]))
#model.add(layers.Activation('elu')) 
#model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D())
    model.add(layers.Dropout(0.2))

    model.add(layers.Conv2D(64, (3, 3), 
                        padding="same", 
                        activation='relu',
                        kernel_initializer='he_uniform'))
                        #kernel_regularizer=keras.regularizers.l2(weight_decay)))
#model.add(layers.Activation('elu')) 
#model.add(layers.BatchNormalization())
#model.add(layers.Conv2D(64, (3, 3), 
#                        padding="same", 
#                        activation='relu',
#                        #kernel_regularizer=keras.regularizers.l2(weight_decay)))
#model.add(layers.Activation('elu')) 
#model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D())
#model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(64, (3, 3), 
                        padding="same", 
                        activation='relu',
                        kernel_initializer='he_uniform'))
                        #kernel_regularizer=keras.regularizers.l2(weight_decay)))
#model.add(layers.Activation('elu')) 
#model.add(layers.BatchNormalization())
#model.add(layers.Conv2D(64, (3, 3), 
#                        padding="same", 
#                        activation='relu',
#                        kernel_regularizer=keras.regularizers.l2(weight_decay)))
#model.add(layers.Activation('elu')) 
#model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D())
    model.add(layers.Dropout(0.2))
          
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(10))

#model.summary()

    #opt_rms = keras.optimizers.RMSprop(lr=0.001,decay=1e-6)
    model.compile(optimizer='adam', #opt_rms,
              loss='categorical_crossentropy',
              metrics=['accuracy'])


    return model

# %%
run()
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 13248/50000 [======>.......................] - ETA: 1:25 - loss: 7.8842 - accuracy: 0.1013
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-0418f379da12> in <module>
#      18     display_results(history)
#      19
# ---> 20 run()
#
# <ipython-input-97-0418f379da12> in run()
#      11
#      12     history = model.fit(train_images, train_labels, epochs=10, batch_size=64,
# ---> 13          validation_data=(test_images, test_labels))
#      14
#      15     _, acc = model.evaluate(test_images, test_labels, verbose=0)
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:
